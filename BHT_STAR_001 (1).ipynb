# %%
import pandas
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pandas.read_csv("/content/open.csv")

# %%
data.shape
data.head()
# Out:
#   Country Code                            Indicator Name     Indicator Code  \
# 0          ABW  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1          ABW                          Urban population        SP.URB.TOTL
# 2          ABW        Urban population growth (annual %)        SP.URB.GROW
# 3          ABW                         Population, total        SP.POP.TOTL
# 4          ABW              Population growth (annual %)        SP.POP.GROW
#
#         1960          1961          1962          1963          1964  \
# 0     50.776     50.761000     50.746000     50.730000     50.715000
# 1  27728.000  28330.000000  28764.000000  29157.000000  29505.000000
# 2        NaN      2.147858      1.520329      1.357042      1.186472
# 3  54608.000  55811.000000  56682.000000  57475.000000  58178.000000
# 4        NaN      2.179059      1.548572      1.389337      1.215721
#
#            1965          1966  ...           2011           2012  \
# ...

# %%
data.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  7.460000e+02  1.200000e+03  1.216000e+03  1.217000e+03  1.218000e+03
# mean   2.131941e+07  1.404569e+07  1.437329e+07  1.529855e+07  1.576599e+07
# std    1.596213e+08  1.361314e+08  1.398711e+08  1.513586e+08  1.552263e+08
# min   -3.667000e+00 -3.667000e+00 -3.667000e+00 -3.667000e+00 -3.667000e+00
# 25%    3.312260e+00  3.303233e+00  3.182910e+00  3.203700e+00  3.253182e+00
# 50%    5.534500e+01  4.213570e+01  4.329580e+01  4.236630e+01  4.380086e+01
# 75%    1.397860e+04  1.814965e+03  1.962319e+03  1.916928e+03  2.059631e+03
# max    2.208000e+09  2.420000e+09  2.483000e+09  2.705000e+09  2.771000e+09
#
#                1965          1966          1967          1968          1969  \
# count  1.223000e+03  1.226000e+03  1.227000e+03  1.231000e+03  1.234000e+03
# mean   1.651827e+07  1.930788e+07  2.023463e+07  2.169692e+07  2.287891e+07
# ...

# %%
data.corr()
# Out:
#           1960      1961      1962      1963      1964      1965      1966  \
# 1960  1.000000  0.999299  0.997029  0.993052  0.989622  0.988706  0.981821
# 1961  0.999299  1.000000  0.998584  0.995870  0.992779  0.992572  0.988183
# 1962  0.997029  0.998584  1.000000  0.999151  0.997644  0.997240  0.989833
# 1963  0.993052  0.995870  0.999151  1.000000  0.999493  0.999433  0.992157
# 1964  0.989622  0.992779  0.997644  0.999493  1.000000  0.999725  0.990333
# ...        ...       ...       ...       ...       ...       ...       ...
# 2016  0.926560  0.929850  0.932110  0.934121  0.936136  0.937316  0.938480
# 2017  0.922291  0.927093  0.929401  0.931450  0.933505  0.934708  0.935890
# 2018  0.919771  0.924699  0.927045  0.929119  0.931201  0.932415  0.933606
# 2019  0.917197  0.922254  0.924639  0.926737  0.928845  0.930070  0.931271
# 2020  0.914611  0.919705  0.922114  0.924237  0.926374  0.927613  0.928824
#
# ...

# %%
# Filter the data for the AUS and GDP per capita of 20 years 
plt.figure(figsize=(30,8))
aus_data = data[(data['Country Code'] == 'AUS')]
aus_data=aus_data[:20]
# Create a line plot
plt.plot(aus_data.iloc[:, 4:].columns, aus_data.iloc[:, 4:].values[0])
plt.title('GDP per capita of the AUS')
plt.xlabel('Year')
plt.ylabel('GDP per capita')
plt.show()

# %%
data['1961'].plot.density(color='green')
plt.title('Density plot for Speeding')
plt.show()

# %%
abc=data[data['Indicator Name']=='Urban population']
abc['2020'].plot.density(color='blue')
plt.title('Density plot for Speeding')
plt.show()

# %%
abc=data[data['Indicator Name']=='Population, total']
abc['2000'].plot.density(color='red')
plt.title('Density plot for Speeding')
plt.show()
